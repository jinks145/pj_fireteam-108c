# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
host = 'fireteam108c-db.ctq6oauek6z5.us-east-2.rds.amazonaws.com:3306'
user = 'admin108c'
password = 'fireteam108c'
database = 'amazon_books'

# %%
engine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{database}')

# %%
connection = engine.connect()

# %%
books_rating = pd.read_sql_table('books_rating', con=connection)
display(books_rating)
# Out:
#           index          Id  \
# 0            47  0802841899
# 1            48  0802841899
# 2            49  0802841899
# 3            50  0802841899
# 4           195  0887402216
# ...         ...         ...
# 174290  2998062  1585676187
# 174291  2998063  1585676187
# 174292  2998064  1585676187
# 174293  2998065  1585676187
# 174294  2998066  1585676187
#
#                                                     Title review/helpfulness  \
# 0       The Church of Christ: A Biblical Ecclesiology ...              74/81
# 1       The Church of Christ: A Biblical Ecclesiology ...                2/3
# 2       The Church of Christ: A Biblical Ecclesiology ...                2/3
# 3       The Church of Christ: A Biblical Ecclesiology ...                3/5
# 4                                 The Battleship Bismarck                9/9
# ...                                                   ...                ...
# 174290                             Anthony Powell: A Life               9/10
# ...

# %%
books_ratings = pd.read_sql_table('books_rating_raw', con=connection)
books_ratings
# Out:
#                  Id                           Title  Price         User_id  \
# 0        1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1        0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2        0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3        0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4        0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
# ...             ...                             ...    ...             ...
# 2999995  B000NSLVCU             The Idea of History    NaN            None
# 2999996  B000NSLVCU             The Idea of History    NaN  A1SMUB9ASL5L9Y
# 2999997  B000NSLVCU             The Idea of History    NaN  A2AQMEKZKK5EE4
# 2999998  B000NSLVCU             The Idea of History    NaN  A18SQGYBKS852K
# 2999999  B000NSLVCU             The Idea of History    NaN            None
#
# ...

# %%
books_ratings = books_ratings.dropna()
books_ratings
# Out:
#                  Id                                              Title  Price  \
# 10       0829814000              Wonderful Worship in Smaller Churches  19.40
# 11       0829814000              Wonderful Worship in Smaller Churches  19.40
# 12       0829814000              Wonderful Worship in Smaller Churches  19.40
# 13       0829814000              Wonderful Worship in Smaller Churches  19.40
# 14       0595344550                      Whispers of the Wicked Saints  10.95
# ...             ...                                                ...    ...
# 2999953  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999954  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999955  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999956  0786182431                   Very Bad Deaths: Library Edition  90.00
# 2999988  0255364520  An End to Welfare Rights: The Rediscovery of I...  18.95
#
# ...

# %%
books_ratings = books_ratings.drop_duplicates()

# %%
ratings_user_tagged = books_ratings[books_ratings["Id"].isin(books_ratings_tagged["Id"])].drop_duplicates().dropna()

# %%
# Out:
#                                                   Title     book_id
# 0                                          "Come to Me"  159467180X
# 1     "Forget Not Love": The Passion of Maximilian K...  0898702755
# 2     "Happiness Is Not My Companion": The Life of G...  0253339049
# 3               "Life Was Never Meant to Be a Struggle"  1561705357
# 4     "Mom, Dad . . . I'm Pregnant": When Your Daugh...  1576834824
# ...                                                 ...         ...
# 9229                           eBay: The Missing Manual  0596006446
# 9230  eMbedded Visual Basic: Windows CE and Pocket P...  0672322773
# 9231                                      mo+th issue 1  0941017680
# 9232      sendmail Desktop Reference (Pocket Reference)  1565922786
# 9233                               tick, tick ... BOOM!  063404169X
#
# [9234 rows x 2 columns]

# %%
ratings_user_tagged = pd.merge(books_ratings, reviewed_tagged_books.get(["Title","book_id"]), on='Title', how='inner')

# %%
ratings_user_tagged.columns
# Out:
# Index(['Id', 'Title', 'Price', 'User_id', 'profileName', 'review/helpfulness',
#        'review/score', 'review/time', 'review/summary', 'review/text',
#        'book_id'],
#       dtype='object')

# %%
res = { k: v.get("book_id", "review/score") for k, v in ratings_user_tagged.groupby('User_id')}
# Out:
# {'A00117421L76WVWG4UX95': 73416    0767908392
#  Name: book_id, dtype: object,
#  'A0015610VMNR0JC9XVL1': 101616    0785263500
#  Name: book_id, dtype: object,
#  'A00264602WCXBHHFPLTQ4': 82500    0394830148
#  Name: book_id, dtype: object,
#  'A00290423P2GEY37XWVAW': 152639    0439376068
#  Name: book_id, dtype: object,
#  'A00841771VHT9WNGU0X3J': 140206    B000OVFJDS
#  Name: book_id, dtype: object,
#  'A0134066213WYQXLTVGYT': 28103    0786108487
#  28381    0786108487
#  Name: book_id, dtype: object,
#  'A013767087QHAT97SBVC': 136345    0310239443
#  Name: book_id, dtype: object,
#  'A01496021AHO2YSV1VTDN': 61147    0394717953
#  Name: book_id, dtype: object,
#  'A0181450OPL6IIRNAJ4R': 100861    0141001968
#  Name: book_id, dtype: object,
#  'A0236983QUCQMORABO03': 87911    1587888432
#  88041    1587888432
#  Name: book_id, dtype: object,
#  'A02524252ND5JWY0NHZO9': 40922    0446577367
#  Name: book_id, dtype: object,
#  'A02560451Q0YN570UHWFP': 148466    0060577347
# ...

# %%
reviewed_books = pd.read_sql_table('reviewed_tagged_books', con=connection)

# %%
reviewed_books["Title", ""]

# %%
books_ratings_tagged = pd.read_sql_table('books_rating', con=connection)

# %%
book_dict_keys = pd.read_csv('book_dict_keys.csv')

# %%
keys =book_dict_keys.sort_values(by='Title').dropna()

# %%
reviewed_tagged_books = pd.read_sql_table('reviewed_tagged_books', con=connection)
reviewed_tagged_books
# Out:
#                                                   Title  review/average_score  \
# 0                                          "Come to Me"              5.000000
# 1     "Forget Not Love": The Passion of Maximilian K...              5.000000
# 2     "Happiness Is Not My Companion": The Life of G...              4.818182
# 3               "Life Was Never Meant to Be a Struggle"              4.411765
# 4     "Mom, Dad . . . I'm Pregnant": When Your Daugh...              4.800000
# ...                                                 ...                   ...
# 9229                           eBay: The Missing Manual              4.888889
# 9230  eMbedded Visual Basic: Windows CE and Pocket P...              4.000000
# 9231                                      mo+th issue 1              4.000000
# 9232      sendmail Desktop Reference (Pocket Reference)              4.000000
# 9233                               tick, tick ... BOOM!              4.428571
#
# ...

# %%
reviewed_tagged_books = pd.merge(reviewed_books, keys, on='Title', how='inner')
reviewed_tagged_books.dropna()["Title"].unique().shape[0]
# Out:
# 9234

# %%
books_ratings_tagged
# Out:
#           index          Id  \
# 0            47  0802841899
# 1            48  0802841899
# 2            49  0802841899
# 3            50  0802841899
# 4           195  0887402216
# ...         ...         ...
# 174290  2998062  1585676187
# 174291  2998063  1585676187
# 174292  2998064  1585676187
# 174293  2998065  1585676187
# 174294  2998066  1585676187
#
#                                                     Title review/helpfulness  \
# 0       The Church of Christ: A Biblical Ecclesiology ...              74/81
# 1       The Church of Christ: A Biblical Ecclesiology ...                2/3
# 2       The Church of Christ: A Biblical Ecclesiology ...                2/3
# 3       The Church of Christ: A Biblical Ecclesiology ...                3/5
# 4                                 The Battleship Bismarck                9/9
# ...                                                   ...                ...
# 174290                             Anthony Powell: A Life               9/10
# ...

# %%
reviewed_tagged_books = reviewed_tagged_books.drop_duplicates(subset='Title', keep='first')

# %%
names = [col for col in reviewed_tagged_books.columns]
new_names = ["Title", "review/average_score", "ratingsCount", "final_genre", "book_id", ]

# %%
reviewed_tagged_books.to_sql('reviewed_tagged_books', con=connection, if_exists='replace', index=False)
# Out:
# 9234

# %%
reviewed_tagged_books
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 reviewed_tagged_books
#
# NameError: name 'reviewed_tagged_books' is not defined

# %%
connection.close()
