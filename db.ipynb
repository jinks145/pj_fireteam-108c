# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('sqlite:///fireteam108c.db')

# %%
connection = engine.connect()

# %%
books_data_test = pd.read_sql_table('books_data', connection)
books_rating_test = pd.read_sql_table('books_rating', connection)
display(books_data_test)
display(books_rating_test)

# books_data_test = pd.read_sql_table('books_data', )
# Out:
#          index                                              Title  \
# 0            0                     Its Only Art If Its Well Hung!
# 1            1                           Dr. Seuss: American Icon
# 2            2              Wonderful Worship in Smaller Churches
# 3            3                      Whispers of the Wicked Saints
# 4            4  Nation Dance: Religion, Identity and Cultural ...
# ...        ...                                                ...
# 212399  212399  The Orphan Of Ellis Island (Time Travel Advent...
# 212400  212400                            Red Boots for Christmas
# 212401  212401                                              Mamaw
# 212402  212402                                  The Autograph Man
# 212403  212403  Student's Solutions Manual for Johnson/Mowry's...
#
#                                               description  \
# 0                                                    None
# ...

# %%
books_rating_test['id'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 books_rating_test['id'].unique()
#
# ...

# %%
books_rating_test[:]
# Out:
# Index(['index', 'Id', 'Title', 'Price', 'User_id', 'profileName',
#        'review/helpfulness', 'review/score', 'review/time', 'review/summary',
#        'review/text'],
#       dtype='object')

# %%
books_rating_test
# Out:
# Index(['index', 'Id', 'Title', 'Price', 'User_id', 'profileName',
#        'review/helpfulness', 'review/score', 'review/time', 'review/summary',
#        'review/text'],
#       dtype='object')

# %%
res = books_data_test['categories'].unique()
pd.DataFrame(res, columns=['categories']).to_csv('categories.csv', index=False)
# set(res)

books_data_test.to_csv('books_data.csv', index=False)

# %%
pd.read_csv("refined_books_data.csv")
# Out:
#          index                                              Title  \
# 0            0                     Its Only Art If Its Well Hung!
# 1            1                           Dr. Seuss: American Icon
# 2            2              Wonderful Worship in Smaller Churches
# 3            3                      Whispers of the Wicked Saints
# 4            5  The Church of Christ: A Biblical Ecclesiology ...
# ...        ...                                                ...
# 171200  212397  The Magic of the Soul: Applying Spiritual Powe...
# 171201  212398               Autodesk Inventor 10 Essentials Plus
# 171202  212399  The Orphan Of Ellis Island (Time Travel Advent...
# 171203  212400                            Red Boots for Christmas
# 171204  212402                                  The Autograph Man
#
#                                               description  \
# 0                                                     NaN
# ...

# %%
connection.close()
